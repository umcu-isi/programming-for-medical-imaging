# %% [raw]
# ---
# title: "Other Programming Languages"
# execute:
#   enabled: true
#   error: true
#   freeze: auto
# ---

# %% [markdown]
# # Heading 1
# ## Heading 1.1
# ### Heading 1.1.1
#
# *italic*
# **bold**
#
# * Item
#     * Sub-item
# * Another item
#
# 1. Numbered item
#     1. Numbered sub-item
#
# ---
#
# > Blockquote
# >
# > Line 2
#
# [A hyperlink](http://www.isi.uu.nl)
#
# Python code block:
# ```python
# def f(x):
#     """a docstring"""
#     return x**2
# ```
#
# C++ code block:
# ```cpp
# for (i=0; i<n; i++) {
#   printf("hello %d\n", i);
#   x += 4;
# }
# ```
#
# Inline LaTeX equations: $e^{i\\pi} + 1 = 0$ and full equation:
# \begin{equation}
# e^x=\sum_{i=0}^\infty \frac{1}{i!}x^i
# \end{equation}
#
# | This    | is    |
# |---------|-------|
# | a       | table |
# | another | row   |
#
# <img src="images/python-logo-pmi.png" width=200>

# %%
# Some python code and output:
import numpy as np
print(np.__version__)
# Out:
# 2.5.1
